# %% [markdown]
# # Gra w papier kanień nozyce
#
# * **Gra jest odporna na uzytkowników nie wpisujacych wskazanych znakow**
# * **Cała rozgrywka jest oparta na losowym generowaniu 3 cyfr, gdzie 0 oznacza papier, 1 oznacza kamień oraz 2 oznacza nozyce**
# * **Zasady gdy sa proste zarówno gracz jak i komputer wystawiaja jedna z 3 mozliwości (papier,kamien,nozyce)**
# * **Papier zawsze wygrywa z kamieniem a przegrywa z nozycami**
# * **Kamien zawsze wygrywa z nozycami a przegrywa z paierem**
# * **Nozyce zawsze wygrywaja z papierem a przegrywaja z kamieniem**
#
# **Powodzenia w grze!**

# %%
from time import *
import random

print('Papier, Kamien czy Nozyce?')
sleep(2)
print('Wpisz:')
sleep(1)
print('k - jeśli kamien')
sleep(1)
print('p - jeśli papier')
sleep(1)
print('n - jesli nozyce')
sleep(2)
i=True
while i == True:
    ruchK = random.sample(range(3), 1)
    if ruchK[0] == 0:
        K='Papier'
    elif ruchK[0] == 1:
        K='Kamien'
    elif ruchK[0] == 2:
        K='Nozyce'
    a=True
    while a==True:
        print('Uwaga zaczynamy!')
        sleep(1)
        print('3')
        sleep(1)
        print('2')
        sleep(1)
        print('1')
        sleep(1)
        print('START!')
        G = input()  
        if G == 'p':
            G='Papier'
            a=False
        elif G == 'k':
            G='Kamien'
            a=False
        elif G == 'n':
            G='Nozyce'
            a=False
        else:
            print('Wybierz jedną z moliwości!')
            sleep(1)
    print(G, 'VS', K )
    sleep(1)
    if (G == 'Kamien' and K == 'Nozyce') or (G == 'Papier' and K == 'Kamien') or (G == 'Nozyce' and K == 'Papier'):
        print('🥳 WYGRANA 🥳')
    elif G == K:
        print('🤝 REMIS 🤝')
    else:
        print('😢 PRZEGRANA 😢')
    sleep(1)
    print('Chcesz zagrać jeszcze raz ?')
    sleep(1)
    j=True
    while j == True:
        print('Wybierz:')
        sleep(1)
        print('t - jesli TAK')
        sleep(1)
        print('n - jesli NIE')
        b = input()
        if b == 'n':
            i = False
            break
        elif b == 't':
            print('Za chwile następna rudna!')
            j= False
            sleep(1.5)
        else:
            print('Podaj t lub n')
            j=True
